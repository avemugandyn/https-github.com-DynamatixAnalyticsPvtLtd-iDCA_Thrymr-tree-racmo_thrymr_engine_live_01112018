# %%
import pandas as pd
import numpy as np

# %%
fdf = pd.read_excel("/home/thrymr/552-python-Workspace/shashank_classfication/upload_N27_parse_30_10.xlsx")

# %%
fdf[(fdf['filetype']=='TICKET')]
# Out:
#                                               filename  \
# 0    2010_0000295_SC5_20181023210361220181005130352...
# 3    2011_0000090_S5L_20181023217264320181005153444...
# 4    2009_0000040_EJH_20181023237224820181008125619...
# 6    2008_0001164_CNO_20181023254500420181009095029...
# 9    2012_0000217_S05_20181023266242620181009134749...
# 11   2010_0000005_CNA_20181023267806620181009141646...
# 12   2008_0000591_CNO_20181023270236520181009155651...
# 17   2013_0000495_CNA_20181023281370620181010100558...
# 18   2013_0000029_S5L_20181023282295720181010102013...
# 21   2016_0000253_S5L_20181023303090120181011072758...
# 24   2012_0000606_CNA_20181023308409920181011094654...
# 28   2008_0000393_PCO_20181023316026020181011120635...
# 32   2017_0000383_S2A_20181023323851720181011142002...
# 36   2013_0000067_CNO_20181023335349420181015090854...
# 38   2008_0000393_PCO_20181023336564020181015092751...
# 41   2018_0000207_S1C_20181023338062220181015095045...
# ...

# %%
type(a[0]),type(a),a.columns
# Out:
# (pandas.core.series.Series,
#  pandas.core.frame.DataFrame,
#  RangeIndex(start=0, stop=4, step=1))

# %%
a.columns = ['A','B','C','D']

# %%
#a.rename(columns={'A':'X'})

# %%
a['B'] = a['B'].astype('str')

# %%
for i,r in a.iterrows():
    print(i,r)
    if i == 10:
        break
# Out:
# 0 filename          2010_0000295_SC5_20181023210361220181005130352...
# filegroup                             20181023210361220181005130352
# ext                                                             pdf
# length                                                           54
# filetype                                                     TICKET
# table_response    {"filepath": "/home/racmo/upload_N27/2010_0000...
# text_response     {"filepath": "/home/racmo/upload_N27/2010_0000...
# Name: 0, dtype: object
# 1 filename          2010_0000295_SC5_20181023210361220181005130352...
# filegroup                             20181023210361220181005130352
# ext                                                             pdf
# length                                                           90
# filetype                                               NOTIFICATION
# table_response               Error:'Polygon' object is not iterable
# ...

# %%
type(a[['filename','filegroup','ext']])
# Out:
# pandas.core.frame.DataFrame

# %%
a[(a['B'] == "0.10291807530670416")]#& (a['B'] == "0.7418153410237361")]
# Out:
#           A                    B         C        D
# 3  0.882847  0.10291807530670416  0.698049  0.23401

# %%
# for i in a.groupby('filegroup'):
#     print(i[0])

# %%
#a.head(11)

# %%
import re
s = "ghcghjgch.pdf sjkhskjdhkj jhjhdjhjsc vhvh.pdf"
word = '.pdf'
for match in re.finditer(word, s):
    a= match.start()-8
    print(a)
    print(s[a:match.end()])
    
s[1:5]
# Out:
# 1
# hcghjgch.pdf
# 33
# jsc vhvh.pdf
# 'hcgh'
